# %% [markdown]
# # Jay Mudgal

# %%
import requests
from bs4 import BeautifulSoup as BS

# %%
req= requests.get("https://www.worldometers.info/gdp/gdp-by-country/")

# %%
req.status_code
# Out:
# 200

# %%
len(req.text)
# Out:
# 129767

# %%
type(req.text)
# Out:
# str

# %%
req.text[:500]
# Out:
# '\n\n<!DOCTYPE html><!--[if IE 8]> <html lang="en" class="ie8"> <![endif]--><!--[if IE 9]> <html lang="en" class="ie9"> <![endif]--><!--[if !IE]><!--> <html lang="en"> <!--<![endif]--> <head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=device-width, initial-scale=1"> <title>GDP by Country - Worldometer</title><meta name="description" content="Countries in the world ranked by Gross Domestic Product (GDP). List and ranking of GDP g'

# %%
print(req.text[:1000])
# Out:
# <!DOCTYPE html><!--[if IE 8]> <html lang="en" class="ie8"> <![endif]--><!--[if IE 9]> <html lang="en" class="ie9"> <![endif]--><!--[if !IE]><!--> <html lang="en"> <!--<![endif]--> <head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=device-width, initial-scale=1"> <title>GDP by Country - Worldometer</title><meta name="description" content="Countries in the world ranked by Gross Domestic Product (GDP). List and ranking of GDP growth, GDP per capita and couuntry share of World's GDP"><!-- Favicon --><link rel="shortcut icon" href="/favicon/favicon.ico" type="image/x-icon"><link rel="apple-touch-icon" sizes="57x57" href="/favicon/apple-icon-57x57.png"><link rel="apple-touch-icon" sizes="60x60" href="/favicon/apple-icon-60x60.png"><link rel="apple-touch-icon" sizes="72x72" href="/favicon/apple-icon-72x72.png"><link rel="apple-touch-icon" sizes="76x76" href="/favicon/apple-icon-76x76.png"><link rel="apple-touch-icon" size
# ...

# %%
soup = BS(req.text,'html.parser') #What is parse Python? In this article,
#parsing is defined as the processing of a piece of python program 
#and converting these codes into machine language. convert in format

# %%
print(soup.head())
# Out:
# [<meta charset="utf-8"/>, <meta content="IE=edge" http-equiv="X-UA-Compatible"/>, <meta content="width=device-width, initial-scale=1" name="viewport"/>, <title>GDP by Country - Worldometer</title>, <meta content="Countries in the world ranked by Gross Domestic Product (GDP). List and ranking of GDP growth, GDP per capita and couuntry share of World's GDP" name="description"/>, <link href="/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>, <link href="/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>, <link href="/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>, <link href="/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>, <link href="/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>, <link href="/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>, <link href="/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>, <link href="/favicon/apple-icon-144
# ...

# %%
print(soup.prettify()[:1000])#tree structure of format easy to undestand 
#utf-8=Unicode Transformation Format
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en" class="ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->
# <!--[if !IE]><!-->
# <html lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    GDP by Country - Worldometer
#   </title>
#   <meta content="Countries in the world ranked by Gross Domestic Product (GDP). List and ranking of GDP growth, GDP per capita and couuntry share of World's GDP" name="description"/>
#   <!-- Favicon -->
#   <link href="/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# ...

# %%
soup.title.text
# Out:
# 'GDP by Country - Worldometer'

# %%
all_paras = soup.find_all('p')
#print(all_paras)
len(all_paras)
# Out:
# 2

# %%
type(all_paras)
# Out:
# bs4.element.ResultSet

# %%
all_table = soup.find_all("table")

# %%
print(len(all_table))
# Out:
# 1

# %%
type(all_table[0].text)
# Out:
# str

# %%
print(all_table[0].text)
# Out:
#    # Country GDP (nominal, 2017)  GDP (abbrev.) GDP  growth Population (2017)  GDP  per capita  Share of World GDP      1 United States $19,485,394,000,000 $19.485 trillion 2.27% 325,084,756 $59,939 24.08%   2 China $12,237,700,479,375 $12.238 trillion 6.90% 1,421,021,791 $8,612 15.12%   3 Japan $4,872,415,104,315 $4.872 trillion 1.71% 127,502,725 $38,214 6.02%   4 Germany $3,693,204,332,230 $3.693 trillion 2.22% 82,658,409 $44,680 4.56%   5 India $2,650,725,335,364 $2.651 trillion 6.68% 1,338,676,785 $1,980 3.28%   6 United Kingdom $2,637,866,340,434 $2.638 trillion 1.79% 66,727,461 $39,532 3.26%   7 France $2,582,501,307,216 $2.583 trillion 1.82% 64,842,509 $39,827 3.19%   8 Brazil $2,053,594,877,013 $2.054 trillion 0.98% 207,833,823 $9,881 2.54%   9 Italy $1,943,835,376,342 $1.944 trillion 1.50% 60,673,701 $32,038 2.40%   10 Canada $1,647,120,175,449 $1.647 trillion 3.05% 36,732,095 $44,841 2.04%   11 Russia $1,578,417,211,937 $1.578 trillion 1.55% 145,530,082 $10,846 1.95%   12 S
# ...

# %%
table= all_table[0]

# %%
type(table.text)
# Out:
# str

# %%
from IPython.display import HTML

# %%
HTML(table.prettify())
# Out:
# <table class="table table-striped table-bordered" id="example2">
#  <thead>
#   <tr>
#    <th>
#     #
#    </th>
#    <th>
#     Country
#    </th>
#    <th>
#     GDP
#     <br/>
#     (nominal, 2017)
#    </th>
#    <th>
#     GDP
#     <br/>
#     (abbrev.)
#    </th>
#    <th>
#     GDP
#     <br/>
#     growth
#    </th>
#    <th>
#     Population
#     <br/>
#     (2017)
#    </th>
#    <th>
#     GDP
#     <br/>
#     per capita
#    </th>
#    <th>
#     Share of
#     <br/>
#     World GDP
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr>
#    <td style="text-align:center">
#     1
#    </td>
#    <td style="font-weight: bold; font-size:17px; text-align:left; padding-left:5px; padding-top:10px; padding-bottom:10px">
#     <a href="/gdp/us-gdp/">
#      United States
#     </a>
#    </td>
#    <td style="font-weight: bold; text-align:right;">
#     $19,485,394,000,000
#    </td>
#    <td style="font-weight: bold; text-align:right;">
#     $19.485 trillion
#    </td>
# ...
